# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
data2017_df = pd.read_csv(r"C:\Users\daric\Desktop\HAPPINESS\data_2017.csv", dtype=object, low_memory=False)

data2017_df.head()
# Out:
#        country happiness_rank happiness_score whisker_high  whisker_low  \
# 0       Norway              1     7.537000179  7.594444821  7.479555538
# 1      Denmark              2     7.521999836  7.581728065  7.462271607
# 2      Iceland              3     7.504000187  7.622030473  7.385969901
# 3  Switzerland              4     7.493999958   7.56177242  7.426227496
# 4      Finland              5     7.468999863  7.527542076   7.41045765
#
#   gdp_per_capita       family life_expectancy      freedom   generosity  \
# 0    1.616463184   1.53352356     0.796666503  0.635422587  0.362012237
# 1    1.482383013  1.551121593     0.792565525  0.626006722  0.355280489
# 2     1.48063302  1.610574007     0.833552122  0.627162635  0.475540221
# 3    1.564979553  1.516911745     0.858131289  0.620070577  0.290549278
# 4    1.443571925  1.540246725      0.80915767  0.617950857  0.245482773
#
#   government_corr dystopia_residual continent social_support population
# ...

# %%
new_2017data_df = data2017_df[['country', 'happiness_rank', 'happiness_score', 'gdp_per_capita','family', 'life_expectancy',
                                   'freedom', 'generosity','government_corr', 'social_support','continent', 'population']].copy()
new_2017data_df.head()
# Out:
#        country happiness_rank happiness_score gdp_per_capita       family  \
# 0       Norway              1     7.537000179    1.616463184   1.53352356
# 1      Denmark              2     7.521999836    1.482383013  1.551121593
# 2      Iceland              3     7.504000187     1.48063302  1.610574007
# 3  Switzerland              4     7.493999958    1.564979553  1.516911745
# 4      Finland              5     7.468999863    1.443571925  1.540246725
#
#   life_expectancy      freedom   generosity government_corr social_support  \
# 0     0.796666503  0.635422587  0.362012237     0.315963835            NaN
# 1     0.792565525  0.626006722  0.355280489     0.400770068            NaN
# 2     0.833552122  0.627162635  0.475540221     0.153526559            NaN
# 3     0.858131289  0.620070577  0.290549278     0.367007285            NaN
# 4      0.80915767  0.617950857  0.245482773     0.382611543            NaN
#
#   continent population
# 0    Europe   5296.324
# ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/World Happiness DB"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['clean_2016']

# %%
new_2017data_df.to_sql(name='clean_2017', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from clean_2017', con=engine).head()
# Out:
#        country happiness_rank happiness_score gdp_per_capita       family  \
# 0       Norway              1     7.537000179    1.616463184   1.53352356
# 1      Denmark              2     7.521999836    1.482383013  1.551121593
# 2      Iceland              3     7.504000187     1.48063302  1.610574007
# 3  Switzerland              4     7.493999958    1.564979553  1.516911745
# 4      Finland              5     7.468999863    1.443571925  1.540246725
#
#   life_expectancy      freedom   generosity government_corr social_support  \
# 0     0.796666503  0.635422587  0.362012237     0.315963835           None
# 1     0.792565525  0.626006722  0.355280489     0.400770068           None
# 2     0.833552122  0.627162635  0.475540221     0.153526559           None
# 3     0.858131289  0.620070577  0.290549278     0.367007285           None
# 4      0.80915767  0.617950857  0.245482773     0.382611543           None
#
#   continent population
# 0    Europe   5296.324
# ...
